# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import sklearn

# %%
df = pd.read_csv(r"C:\Users\hp\Downloads\haberman.csv")
df.head()
# Out:
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1
# 2   30    65      0       1
# 3   31    59      2       1
# 4   31    65      4       1

# %%
df.shape
# Out:
# (305, 4)

# %%
df.columns
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
df["status"].value_counts()
# Out:
# 1    225
# 2     80
# Name: status, dtype: int64

# %%
df.isnull().sum()
# Out:
# age       0
# year      0
# nodes     0
# status    0
# dtype: int64

# %%
sb.heatmap(df.isnull(), yticklabels = False)
# Out:
# <AxesSubplot:>

# %%
sb.set_style("whitegrid")
sb.countplot(x = "status", data = df);

# %%
df.describe()
# Out:
#               age        year       nodes      status
# count  305.000000  305.000000  305.000000  305.000000
# mean    52.357377   62.868852    4.032787    1.262295
# std     10.678010    3.242783    7.200528    0.440605
# min     30.000000   58.000000    0.000000    1.000000
# 25%     44.000000   60.000000    0.000000    1.000000
# 50%     52.000000   63.000000    1.000000    1.000000
# 75%     60.000000   66.000000    4.000000    2.000000
# max     78.000000   69.000000   52.000000    2.000000

# %%
df.corr()
# Out:
#              age      year     nodes    status
# age     1.000000  0.105192 -0.061375  0.053424
# year    0.105192  1.000000 -0.005169  0.003435
# nodes  -0.061375 -0.005169  1.000000  0.289670
# status  0.053424  0.003435  0.289670  1.000000

# %%
sb.set_style("whitegrid")
sb.FacetGrid(df, hue = "status").map(plt.scatter, "age", "year").add_legend();

# %%
sb.set_style("whitegrid")
sb.FacetGrid(df, hue = "status").map(plt.scatter, "age", "nodes").add_legend();

# %%
sb.pairplot(df, hue = "status", vars = ["age", "year", "nodes"], palette = "rainbow");

# %%
live_score = df.loc[df["status"] == 1]
death_score = df.loc[df["status"] == 2]

plt.plot(live_score["age"], np.zeros_like(live_score["age"]), "o");
plt.plot(death_score["age"], np.zeros_like(death_score["age"]), "o");

# %%
sb.FacetGrid(df, hue = "status").map(sb.distplot, "year").add_legend();
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-1c2c45d63934> in <module>
# ...

# %%
sb.distplot(df["age"], color = "darkred");
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sb.histplot(df["age"], color = "darkred");

# %%
sb.boxplot(x = "status", y = "age", data = df);

# %%
sb.boxplot(x = "status", y = "nodes", data = df);
